# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import  GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn import svm

# %%
df=pd.read_csv("D:\Aicte internship\Datasets\parkinsons.csv")
df.shape
# Out:
# (195, 24)

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
df.isna().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...          D2         PPE
# count   195.000000    195.000000  ...  195.000000  195.000000
# mean    154.228641    197.104918  ...    2.381826    0.206552
# std      41.390065     91.491548  ...    0.382799    0.090119
# min      88.333000    102.145000  ...    1.423287    0.044539
# 25%     117.572000    134.862500  ...    2.099125    0.137451
# 50%     148.790000    175.829000  ...    2.361532    0.194052
# 75%     182.769000    224.205500  ...    2.636456    0.252980
# max     260.105000    592.030000  ...    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %% [markdown]
# 1---->with parkinsons
# 0----->without parkinsons

# %%
df.groupby('status').mean(numeric_only=True)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread2        D2       PPE
# status                                           ...
# 0        181.937771    223.636750    145.207292  ...  0.160292  2.154491  0.123017
# 1        145.180762    188.441463    106.893558  ...  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
X=df.drop(columns=['name','status'],axis=1)
Y=df['status']

# %%
print(X)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread2        D2       PPE
# 0        119.992       157.302        74.997  ...  0.266482  2.301442  0.284654
# 1        122.400       148.650       113.819  ...  0.335590  2.486855  0.368674
# 2        116.682       131.111       111.555  ...  0.311173  2.342259  0.332634
# 3        116.676       137.871       111.366  ...  0.334147  2.405554  0.368975
# 4        116.014       141.781       110.655  ...  0.234513  2.332180  0.410335
# ..           ...           ...           ...  ...       ...       ...       ...
# 190      174.188       230.978        94.261  ...  0.121952  2.657476  0.133050
# 191      209.516       253.017        89.488  ...  0.129303  2.784312  0.168895
# 192      174.688       240.005        74.287  ...  0.158453  2.679772  0.131728
# 193      198.764       396.961        74.904  ...  0.207454  2.138608  0.123306
# 194      214.289       260.277        77.973  ...  0.190667  2.555477  0.148569
#
# [195 rows x 22 columns]

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,stratify=Y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %%
#sc=StandardScaler()

# %%
#sc.fit(X_train)
#X_train=sc.transform(X_train)
#X_test=sc.transform(X_test)

# %%
print(X_train)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread2        D2       PPE
# 13       139.173       179.139        76.556  ...  0.254989  2.519422  0.199889
# 142      198.458       219.290       148.691  ...  0.310746  2.465528  0.209863
# 174      117.004       144.466        99.923  ...  0.229298  1.872946  0.163118
# 113      210.141       232.706       185.258  ...  0.250283  2.489191  0.177807
# 88       173.898       211.350        74.677  ...  0.299793  3.007096  0.194052
# ..           ...           ...           ...  ...       ...       ...       ...
# 123      182.018       197.173        79.187  ...  0.142466  2.174306  0.215558
# 190      174.188       230.978        94.261  ...  0.121952  2.657476  0.133050
# 109      193.030       208.900        80.297  ...  0.278679  2.608749  0.185668
# 153      121.345       139.644        98.250  ...  0.246404  2.013530  0.168581
# 144      202.544       241.350       164.168  ...  0.220617  2.576563  0.159777
#
# [156 rows x 22 columns]

# %%
print(X_test)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)
# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
x=X
y=Y
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Define models
models = {
    "Logistic Regression": LogisticRegression(max_iter=200),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "Support Vector Machine": SVC()
}

# Train and evaluate models
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{name}: {accuracy:.4f}")
# Out:
# Logistic Regression: 0.8974
# Random Forest: 0.9487
# d:\Aicte internship\disease_outbreak_env\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Gradient Boosting: 0.9487
# Support Vector Machine: 0.8462

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,stratify=Y, random_state=2)
model=svm.SVC()
model.fit(X_train,Y_train)
# Out:
# SVC()

# %%
X_train_pred=model.predict(X_train)
train_accuracy=accuracy_score(Y_train,X_train_pred)
print(train_accuracy)
# Out:
# 0.8141025641025641

# %%
X_test_pred=model.predict(X_test)
train_accuracy=accuracy_score(Y_test,X_test_pred)
print(train_accuracy)
# Out:
# 0.8461538461538461

# %%
input_data=(201.464,210.565,195.708,0.00198,0.00001,0.00105,0.00115,0.00314,0.01194,0.107,0.00586,0.0076,0.00957,0.01758,0.00135,31.732,0.344252,0.742737,-7.777685,0.170183,2.447064,0.05761)
input_np=np.asarray(input_data)
input_data_reshape = input_np.reshape(1, -1)

# Standardize correctly
#std = sc.transform(input_data_reshape)
#print(std)
predict=model.predict(std)
if (predict[0]==0):
    print("normal person")
else:
    print("has parkinsons")
# Out:
# has parkinsons
# d:\Aicte internship\disease_outbreak_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
input_data=(237.22600,247.32600,225.22700,0.00298,0.00001,0.00169,0.00182,0.00507,0.01752,0.16400,0.01035,0.01024,0.01133,0.03104,0.00740,22.73600,0.305062,0.654172,-7.310550,0.098648,2.416838,0.095032)
input_np=np.asarray(input_data)
input_data_reshape = input_np.reshape(1, -1)

# Standardize correctly
#std = sc.transform(input_data_reshape)
#print(std)
predict=model.predict(input_data_reshape)
if (predict[0]==0):
    print("normal person")
else:
    print("has parkinsons")
# Out:
# normal person
# d:\Aicte internship\disease_outbreak_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
filename='parkinsons.sav'
pickle.dump(model,open(filename,'wb'))

# %%
load_mdl=pickle.load(open(filename,'rb'))

# %%
input_data=(237.22600,247.32600,225.22700,0.00298,0.00001,0.00169,0.00182,0.00507,0.01752,0.16400,0.01035,0.01024,0.01133,0.03104,0.00740,22.73600,0.305062,0.654172,-7.310550,0.098648,2.416838,0.095032)
input_np=np.asarray(input_data)
input_data_reshape = input_np.reshape(1, -1)

# Standardize correctly
#std = sc.transform(input_data_reshape)
#print(std)
predict=load_mdl.predict(input_data_reshape)
if (predict[0]==0):
    print("normal person")
else:
    print("has parkinsons")
# Out:
# normal person
# d:\Aicte internship\disease_outbreak_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
input_data=(184.05500,196.53700,166.97700,0.00258,0.00001,0.00134,0.00147,0.00403,0.01463,0.13200,0.00742,0.00901,0.01234,0.02226,0.00257,26.45300,0.306443,0.759203,-7.044105,0.063412,2.361532,0.115730)
input_np=np.asarray(input_data)
input_data_reshape = input_np.reshape(1, -1)

# Standardize correctly
#std = sc.transform(input_data_reshape)
#print(std)
predict=load_mdl.predict(input_data_reshape)
if (predict[0]==0):
    print("normal person")
else:
    print("has parkinsons")
# Out:
# has parkinsons
# d:\Aicte internship\disease_outbreak_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
